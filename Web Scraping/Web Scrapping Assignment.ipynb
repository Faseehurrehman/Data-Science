# %% [markdown]
# ## Web Scrapping
# ### 1 - Dawn Articles
# ### 2 - Top Science Fiction Movies
# ### 3 - Web Scrapping From Multiple Pages
# ### 4 - Using API

# %% [markdown]
# # 1 - Dawn Articles

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
webpage = requests.get('https://www.dawn.com/').text

# %%
soup=BeautifulSoup(webpage,'html.parser')

# %%
data = soup.find_all('article',attrs={'class':'story'})

# %%
data
# Out:
# [<article class="story box mb-2 pb-1" data-id="1717321" data-layout="story">
#  <!-- box/label -->
#  <span class="badge inline-flex text-3 font-normal rounded theme theme-default theme--live align-middle" dir="auto" id="live"><span>Live </span></span>
#  <!-- box/title title-bold-playfairdisplay-pb:1-text:5 -->
#  <h2 class="story__title text-5 font-bold font-playfair-display leading-tight pb-1" data-id="1717321" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717321/long-march-day-2-marriyum-rules-out-negotiations-with-imran-khan">Long march day 2: Marriyum rules out negotiations with Imran Khan</a></h2>
#  <!-- box/image -->
#  <figure class="media media--fill sm:w-full w-full mb-1">
#  <div class="media__item"><a href="https://www.dawn.com/news/1717321/long-march-day-2-marriyum-rules-out-negotiations-with-imran-khan" title=""><picture><img alt="Long march day 2: Marriyum rules out negotiations with Imran Khan" src="https://i.dawn.com/medium/2022/10/291627156b6aa44.png?r=163019"/></picture></a></div>
#  </figure>
#  <!-- box/excerpt -->
#  <div class="story__excerpt text-3 font-georgia mb-1.5" dir="auto">March resumes from Lahore's Shahdara and will make a pit stop in Kamoke at the end of the day.
#
#      </div>
#  <!-- box/date --><span class="story__time text-2.5 text-gray-400 font-arial block"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2022-10-29T16:30:54+05:00"><span class="timestamp__calendar">29 Oct, 2022</span> <span class="timestamp__time">04:30pm</span></span></span> </article>,
#  <article class="story box mb-1 pt-1 border-t border-gray-200 border-b border-gray-200 pb-3" data-id="1717539" data-layout="story">
#  <!-- box/title title-bold-playfairdisplay-pt:1-pb:1-text:4-sm:text:3.5 -->
#  <h2 class="story__title text-4 sm:text-3.5 font-bold font-playfair-display leading-tight pt-1 pb-1" data-id="1717539" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717539/pakistani-prisoner-saifullah-paracha-released-from-guantanamo-bay-after-18-years">Pakistani prisoner Saifullah Paracha released from Guantanamo Bay after 18 years</a></h2>
#  <!-- box/image -->
#  <figure class="media media--focus w-1/4 float-left mb-0 mr-4">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717539/pakistani-prisoner-saifullah-paracha-released-from-guantanamo-bay-after-18-years" title=""><picture><img alt="Pakistani prisoner Saifullah Paracha released from Guantanamo Bay after 18 years" src="https://i.dawn.com/medium/2022/10/29123714381fada.jpg?r=123912"/></picture></a></div>
#  </figure>
#  <!-- box/excerpt -->
#  <div class="story__excerpt leading-5 text-3.25 font-georgia mb-1" dir="auto">Paracha repatriated to Pakistan after "extensive inter-agency process", says FO; US captured him in 2003 and shifted him to Guantanamo in 2004.
#
#      </div>
#  <!-- box/date --><span class="story__time text-2.5 text-gray-400 font-arial block"><span class="timestamp--label">Published</span> <span class="timestamp--time timeago" title="2022-10-29T12:51:49+05:00"><span class="timestamp__calendar">29 Oct, 2022</span> <span class="timestamp__time">12:51pm</span></span></span> </article>,
#  <article class="story box mb-1 border-b border-gray-200 pb-3" data-id="1717558" data-layout="story">
#  <!-- box/title title-bold-playfairdisplay-pt:1-pb:1-text:4-sm:text:3.5 -->
#  <h2 class="story__title text-4 sm:text-3.5 font-bold font-playfair-display leading-tight pt-1 pb-1" data-id="1717558" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717558/2-army-soldiers-martyred-in-exchange-of-fire-with-terrorists-in-dera-ismail-khan">2 army soldiers martyred in exchange of fire with terrorists in Dera Ismail Khan</a></h2>
#  <!-- box/excerpt -->
#  <div class="story__excerpt leading-5 text-3.25 font-georgia mb-1" dir="auto">ISPR says sanitisation of the area is being carried out to eliminate any terrorists found in the vicinity.
#
#      </div>
#  <!-- box/date --><span class="story__time text-2.5 text-gray-400 font-arial block"><span class="timestamp--label">Published</span> <span class="timestamp--time timeago" title="2022-10-29T16:53:37+05:00"><span class="timestamp__calendar">29 Oct, 2022</span> <span class="timestamp__time">04:53pm</span></span></span> </article>,
#  <article class="story box mb-1 border-b border-gray-200 pb-3" data-id="1717533" data-layout="story">
#  <!-- box/title title-bold-playfairdisplay-pt:1-pb:1-text:4-sm:text:3.5 -->
#  <h2 class="story__title text-4 sm:text-3.5 font-bold font-playfair-display leading-tight pt-1 pb-1" data-id="1717533" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717533/pti-terminates-faisal-vawdas-party-membership">PTI terminates Faisal Vawda’s party membership</a></h2>
#  <!-- box/image -->
#  <figure class="media media--focus w-1/4 float-left mb-0 mr-4">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717533/pti-terminates-faisal-vawdas-party-membership" title=""><picture><img alt="PTI terminates Faisal Vawda’s party membership" src="https://i.dawn.com/medium/2022/10/29121303fcbf1d1.jpg?r=121324"/></picture></a></div>
#  </figure>
#  <!-- box/excerpt -->
#  <div class="story__excerpt leading-5 text-3.25 font-georgia mb-1" dir="auto">Termination follows show-cause notice issued to Faisal due to his press conference.
#
#      </div>
#  <!-- box/date --><span class="story__time text-2.5 text-gray-400 font-arial block"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2022-10-29T14:05:52+05:00"><span class="timestamp__calendar">29 Oct, 2022</span> <span class="timestamp__time">02:05pm</span></span></span> </article>,
#  <article class="story box mb-1 border-b border-gray-200 pb-3" data-id="1717544" data-layout="story">
#  <!-- box/title title-bold-playfairdisplay-pt:1-pb:1-text:4-sm:text:3.5 -->
#  <h2 class="story__title text-4 sm:text-3.5 font-bold font-playfair-display leading-tight pt-1 pb-1" data-id="1717544" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717544/police-round-up-34-suspects-for-allegedly-lynching-two-telecom-workers-in-karachis-machhar-colony">Police round up 34 suspects for allegedly lynching two telecom workers in Karachi’s Machhar Colony</a></h2>
#  <!-- box/excerpt -->
#  <div class="story__excerpt leading-5 text-3.25 font-georgia mb-1" dir="auto">Vigilante mob lync­hed two men and torched their vehicle yesterday after rumours spread that they were kidnappers.
#
#      </div>
#  <!-- box/date --><span class="story__time text-2.5 text-gray-400 font-arial block"><span class="timestamp--label">Published</span> <span class="timestamp--time timeago" title="2022-10-29T13:54:27+05:00"><span class="timestamp__calendar">29 Oct, 2022</span> <span class="timestamp__time">01:54pm</span></span></span> </article>,
#  <article class="story box mb-1 border-b border-gray-200 pb-3" data-id="1717495" data-layout="story">
#  <!-- box/title title-bold-playfairdisplay-pt:1-pb:1-text:4-sm:text:3.5 -->
#  <h2 class="story__title text-4 sm:text-3.5 font-bold font-playfair-display leading-tight pt-1 pb-1" data-id="1717495" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717495/coalition-raps-pti-chief-for-creating-chaos">Coalition raps PTI chief for creating ‘chaos’
#  </a></h2>
#  <!-- box/image -->
#  <figure class="media media--focus w-1/4 float-left mb-0 mr-4">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717495/coalition-raps-pti-chief-for-creating-chaos" title=""><picture><img alt="Coalition raps PTI chief for creating ‘chaos’" src="https://i.dawn.com/medium/2022/10/635c9b53ae518.jpg"/></picture></a></div>
#  </figure>
#  <!-- box/excerpt -->
#  <div class="story__excerpt leading-5 text-3.25 font-georgia mb-1" dir="auto">Leaders of the ruling coalition parties slam PTI Chairman chief Imran Khan for "breaking the Constitution”.
#
#      </div>
#  <!-- box/date --><span class="story__time text-2.5 text-gray-400 font-arial block"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2022-10-29T08:20:02+05:00"><span class="timestamp__calendar">29 Oct, 2022</span> <span class="timestamp__time">08:20am</span></span></span> </article>,
#  <article class="story box mb-1 border-b border-gray-200 pb-3" data-id="1717498" data-layout="story">
#  <!-- box/title title-bold-playfairdisplay-pt:1-pb:1-text:4-sm:text:3.5 -->
#  <h2 class="story__title text-4 sm:text-3.5 font-bold font-playfair-display leading-tight pt-1 pb-1" data-id="1717498" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717498/imran-begins-long-march-with-guns-aimed-at-spy-chief">Imran begins long march with guns aimed at spy chief
#  </a></h2>
#  <!-- box/image -->
#  <figure class="media media--focus w-1/4 float-left mb-0 mr-4">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717498/imran-begins-long-march-with-guns-aimed-at-spy-chief" title=""><picture><img alt="Imran begins long march with guns aimed at spy chief" src="https://i.dawn.com/medium/2022/10/635c97920855b.jpg"/></picture></a></div>
#  </figure>
#  <!-- box/excerpt -->
#  <div class="story__excerpt leading-5 text-3.25 font-georgia mb-1" dir="auto">Imran says ISI DG delivered ‘political presser’, conveniently ignored ‘group of thieves’.
#
#      </div>
#  <!-- box/date --><span class="story__time text-2.5 text-gray-400 font-arial block"><span class="timestamp--label">Published</span> <span class="timestamp--time timeago" title="2022-10-29T07:56:45+05:00"><span class="timestamp__calendar">29 Oct, 2022</span> <span class="timestamp__time">07:56am</span></span></span> </article>,
#  <article class="story box mb-1 border-b border-gray-200 pb-3" data-id="1717466" data-layout="story">
#  <!-- box/title title-bold-playfairdisplay-pt:1-pb:1-text:4-sm:text:3.5 -->
#  <h2 class="story__title text-4 sm:text-3.5 font-bold font-playfair-display leading-tight pt-1 pb-1" data-id="1717466" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717466/investigators-find-bullet-in-arshad-sharifs-body">Investigators find ‘bullet’ in Arshad Sharif’s body
#  </a></h2>
#  <!-- box/image -->
#  <figure class="media media--focus w-1/4 float-left mb-0 mr-4">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717466/investigators-find-bullet-in-arshad-sharifs-body" title=""><picture><img alt="Investigators find ‘bullet’ in Arshad Sharif’s body" src="https://i.dawn.com/medium/2022/10/635ca6628b7db.jpg"/></picture></a></div>
#  </figure>
#  <!-- box/excerpt -->
#  <div class="story__excerpt leading-5 text-3.25 font-georgia mb-1" dir="auto">Wound mark on the chest shows bullets fired from behind, sources privy to autopsy say; ARY official seeks UN probe.
#
#      </div>
#  <!-- box/date --><span class="story__time text-2.5 text-gray-400 font-arial block"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2022-10-29T09:06:44+05:00"><span class="timestamp__calendar">29 Oct, 2022</span> <span class="timestamp__time">09:06am</span></span></span> </article>,
#  <article class="story box mb-1 border-b border-gray-200 pb-3" data-id="1717459" data-layout="story">
#  <!-- box/title title-bold-playfairdisplay-pt:1-pb:1-text:4-sm:text:3.5 -->
#  <h2 class="story__title text-4 sm:text-3.5 font-bold font-playfair-display leading-tight pt-1 pb-1" data-id="1717459" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717459/weekly-inflation-surges-to-record-413pc-as-energy-food-prices-spike">Weekly inflation surges to record 4.13pc as energy, food prices spike
#  </a></h2>
#  <!-- box/image -->
#  <figure class="media media--focus w-1/4 float-left mb-0 mr-4">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717459/weekly-inflation-surges-to-record-413pc-as-energy-food-prices-spike" title=""><picture><img alt="Weekly inflation surges to record 4.13pc as energy, food prices spike" src="https://i.dawn.com/medium/2022/10/635c53b7d856c.jpg?r=073027"/></picture></a></div>
#  </figure>
#  <!-- box/excerpt -->
#  <div class="story__excerpt leading-5 text-3.25 font-georgia mb-1" dir="auto">On a year-on-year basis, the weekly inflation recorded an increase of 30.68pc.
#
#      </div>
#  <!-- box/date --><span class="story__time text-2.5 text-gray-400 font-arial block"><span class="timestamp--label">Published</span> <span class="timestamp--time timeago" title="2022-10-29T07:30:27+05:00"><span class="timestamp__calendar">29 Oct, 2022</span> <span class="timestamp__time">07:30am</span></span></span> </article>,
#  <article class="story box mb-1 pb-3" data-id="1717493" data-layout="story">
#  <!-- box/title title-bold-playfairdisplay-pt:1-pb:1-text:4-sm:text:3.5 -->
#  <h2 class="story__title text-4 sm:text-3.5 font-bold font-playfair-display leading-tight pt-1 pb-1" data-id="1717493" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717493/fia-summons-qureshi-on-nov-1-for-probe-into-cipher-audio-leak">FIA summons Qureshi on Nov 1 for probe into cipher audio leak
#  </a></h2>
#  <!-- box/image -->
#  <figure class="media media--focus w-1/4 float-left mb-0 mr-4">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717493/fia-summons-qureshi-on-nov-1-for-probe-into-cipher-audio-leak" title=""><picture><img alt="FIA summons Qureshi on Nov 1 for probe into cipher audio leak" src="https://i.dawn.com/medium/2022/10/635c9f347f6c2.png"/></picture></a></div>
#  </figure>
#  <!-- box/excerpt -->
#  <div class="story__excerpt leading-5 text-3.25 font-georgia mb-1" dir="auto">Qureshi is expected to be questioned regarding the cipher during the ongoing inquiry into the audio leaks, sources say.
#
#      </div>
#  <!-- box/date --><span class="story__time text-2.5 text-gray-400 font-arial block"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2022-10-29T08:35:29+05:00"><span class="timestamp__calendar">29 Oct, 2022</span> <span class="timestamp__time">08:35am</span></span></span> </article>,
#  <article class="story box font-serif" data-id="1717376" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media__icon-video sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.youtube.com/watch?v=x02OtEnPunQ" title=""><picture><img alt="‘The C Word’ Nobody Likes Talking About" src="https://i.ytimg.com/vi/x02OtEnPunQ/mqdefault.jpg"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-center -->
#  <h2 class="story__title text-center font-bold" data-id="1717376" data-layout="story" dir="auto"><a class="story__link" href="https://www.youtube.com/watch?v=x02OtEnPunQ">‘The C Word’ Nobody Likes Talking About </a></h2>
#  </article>,
#  <article class="story box font-serif" data-id="1717373" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media__icon-video sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.youtube.com/watch?v=Hm7otyHaKdM" title=""><picture><img alt="Dispatch from Washington: ‘The DG ISI Presser Was A Political Move’" src="https://i.ytimg.com/vi/Hm7otyHaKdM/mqdefault.jpg"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-center -->
#  <h2 class="story__title text-center font-bold" data-id="1717373" data-layout="story" dir="auto"><a class="story__link" href="https://www.youtube.com/watch?v=Hm7otyHaKdM">Dispatch from Washington: ‘The DG ISI Presser Was A Political Move’ </a></h2>
#  </article>,
#  <article class="story box font-serif" data-id="1717184" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media__icon-video sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.youtube.com/watch?v=HtyPmeg3-y4" title=""><picture><img alt="‘Today’s presser has drawn the battle lines’" src="https://i.ytimg.com/vi/HtyPmeg3-y4/mqdefault.jpg"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-center -->
#  <h2 class="story__title text-center font-bold" data-id="1717184" data-layout="story" dir="auto"><a class="story__link" href="https://www.youtube.com/watch?v=HtyPmeg3-y4">‘Today’s presser has drawn the battle lines’ </a></h2>
#  </article>,
#  <article class="story box font-serif" data-id="1717174" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media__icon-video sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.youtube.com/watch?v=oGEFl6-uvos" title=""><picture><img alt="‘No political process in Pakistan can be street-led’" src="https://i.ytimg.com/vi/oGEFl6-uvos/mqdefault.jpg"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-center -->
#  <h2 class="story__title text-center font-bold" data-id="1717174" data-layout="story" dir="auto"><a class="story__link" href="https://www.youtube.com/watch?v=oGEFl6-uvos">‘No political process in Pakistan can be street-led’ </a></h2>
#  </article>,
#  <article class="story box font-serif" data-id="1717026" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media__icon-video sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.youtube.com/watch?v=lbCbs-WcVy8" title=""><picture><img alt="Post-2014, India is uncomfortable talking about human rights within India" src="https://i.ytimg.com/vi/lbCbs-WcVy8/mqdefault.jpg"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-center -->
#  <h2 class="story__title text-center font-bold" data-id="1717026" data-layout="story" dir="auto"><a class="story__link" href="https://www.youtube.com/watch?v=lbCbs-WcVy8">Post-2014, India is uncomfortable talking about human rights within India </a></h2>
#  </article>,
#  <article class="story box sm:mb-4 sm:pb-0 mb-2 pb-1 border-b border-gray-200 sm:border-none" data-id="1717514" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--fill sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.dawn.com/news/1717514/editorial-it-is-folly-of-the-highest-order-if-indias-rulers-believe-gb-or-ajk-can-be-taken-by-force" title=""><picture><img alt="Editorial: It is folly of the highest order if India’s rulers believe GB or AJK can be taken by force" src="https://i.dawn.com/medium/2022/10/635c9d7b790e2.jpg"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-text:4-sm:text:3.25-center-pt:1.5-sm:pt:1-pb:1-sm:pb:0 -->
#  <h2 class="story__title text-4 sm:text-3.25 text-center font-bold font-playfair-display leading-tight pt-1.5 pb-1" data-id="1717514" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717514/editorial-it-is-folly-of-the-highest-order-if-indias-rulers-believe-gb-or-ajk-can-be-taken-by-force">Editorial: It is folly of the highest order if India’s rulers believe GB or AJK can be taken by force
#  </a></h2>
#  </article>,
#  <article class="story box sm:mb-4 sm:pb-0 mb-2 pb-1 border-b border-gray-200 sm:border-none" data-id="1717515" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--fill sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.dawn.com/news/1717515/democratising-appointments-to-the-supreme-court" title=""><picture><img alt="Democratising appointments to the Supreme Court" src="https://i.dawn.com/medium/2022/10/29083619597ee1a.png?r=083623"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-text:4-sm:text:3.25-center-pt:1.5-sm:pt:1-pb:1-sm:pb:0 -->
#  <h2 class="story__title text-4 sm:text-3.25 text-center font-bold font-playfair-display leading-tight pt-1.5 pb-1" data-id="1717515" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717515/democratising-appointments-to-the-supreme-court">Democratising appointments to the Supreme Court</a></h2>
#  </article>,
#  <article class="story box sm:mb-4 sm:pb-0 mb-2 pb-1 border-b border-gray-200 sm:border-none" data-id="1717177" data-layout="story">
#  <!-- box/image -->
#  <figure class="media sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.dawn.com/news/1717177/will-the-army-really-quit-meddling-in-politics-for-good" title=""><picture><img alt="Will the army really quit meddling in politics for good?" src="https://i.dawn.com/medium/2022/10/27175906e8c8dd0.jpg?r=143749"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-text:4-sm:text:3.25-center-pt:1.5-sm:pt:1-pb:1-sm:pb:0 -->
#  <h2 class="story__title text-4 sm:text-3.25 text-center font-bold font-playfair-display leading-tight pt-1.5 pb-1" data-id="1717177" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717177/will-the-army-really-quit-meddling-in-politics-for-good">Will the army really quit meddling in politics for good?</a></h2>
#  </article>,
#  <article class="story box mb-2 pb-2 border-b border-gray-200" data-id="1717521" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--focus w-1/5 float-right mb-0 ml-3">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717521/sisters-shouldnt-have-to-be-answerable-ali-gul-pir-anoushey-ashraf-defend-feroze-khans-sisters" title=""><picture><img alt="‘Sisters shouldn’t have to be answerable’: Ali Gul Pir, Anoushey Ashraf defend Feroze Khan’s sisters" src="https://i.dawn.com/thumbnail/2022/10/2911221989abbb0.png?r=112349"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-text:3.5-sm:text:3 -->
#  <h2 class="story__title text-3.5 sm:text-3 font-bold font-playfair-display leading-snug" data-id="1717521" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717521/sisters-shouldnt-have-to-be-answerable-ali-gul-pir-anoushey-ashraf-defend-feroze-khans-sisters">‘Sisters shouldn’t have to be answerable’: Ali Gul Pir, Anoushey Ashraf defend Feroze Khan’s sisters
#  </a></h2>
#  </article>,
#  <article class="story box mb-2 pb-2 border-b border-gray-200" data-id="1717516" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--focus w-1/5 float-right mb-0 ml-3">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717516/rishi-sunaks-rise-to-uk-pm" title=""><picture><img alt="Rishi Sunak’s rise to UK PM" src="https://i.dawn.com/thumbnail/2022/10/29084801eefbd1b.jpg?r=084841"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-text:3.5-sm:text:3 -->
#  <h2 class="story__title text-3.5 sm:text-3 font-bold font-playfair-display leading-snug" data-id="1717516" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717516/rishi-sunaks-rise-to-uk-pm">Rishi Sunak’s rise to UK PM</a></h2>
#  </article>,
#  <article class="story box mb-2 pb-2 border-b border-gray-200" data-id="1717553" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--focus w-1/5 float-right mb-0 ml-3">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717553/from-luxurious-lifestyles-to-fiery-fights-were-secretly-living-for-netflixs-new-show-dubai-bling-and-so-are-netizens" title=""><picture><img alt="From luxurious lifestyles to fiery fights, we’re secretly living for Netflix’s new show Dubai Bling and so are netizens" src="https://i.dawn.com/thumbnail/2022/10/291507219e08023.png?r=150817"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-text:3.5-sm:text:3 -->
#  <h2 class="story__title text-3.5 sm:text-3 font-bold font-playfair-display leading-snug" data-id="1717553" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717553/from-luxurious-lifestyles-to-fiery-fights-were-secretly-living-for-netflixs-new-show-dubai-bling-and-so-are-netizens">From luxurious lifestyles to fiery fights, we’re secretly living for Netflix’s new show Dubai Bling and so are netizens</a></h2>
#  </article>,
#  <article class="story box mb-2 pb-2 border-b border-gray-200" data-id="1717285" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--focus w-1/5 float-right mb-0 ml-3">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717285/editorial-it-is-stunning-how-spectacularly-the-pti-and-the-military-have-fallen-out" title=""><picture><img alt="Editorial: It is stunning how spectacularly the PTI and the military have fallen out" src="https://i.dawn.com/thumbnail/2022/10/635b506959c8a.png"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-text:3.5-sm:text:3 -->
#  <h2 class="story__title text-3.5 sm:text-3 font-bold font-playfair-display leading-snug" data-id="1717285" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717285/editorial-it-is-stunning-how-spectacularly-the-pti-and-the-military-have-fallen-out">Editorial: It is stunning how spectacularly the PTI and the military have fallen out
#  </a></h2>
#  </article>,
#  <article class="story box mb-2 pb-2 border-b border-gray-200" data-id="1717543" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--focus w-1/5 float-right mb-0 ml-3">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717543/release-of-farhan-saeed-iman-ali-sonya-hussyn-and-feroze-khan-starrer-tich-button-postponed-once-again" title=""><picture><img alt="Release of Farhan Saeed, Iman Ali, Sonya Hussyn and Feroze Khan starrer Tich Button postponed once again" src="https://i.dawn.com/thumbnail/2022/10/2913191540c4844.png?r=131936"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-text:3.5-sm:text:3 -->
#  <h2 class="story__title text-3.5 sm:text-3 font-bold font-playfair-display leading-snug" data-id="1717543" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717543/release-of-farhan-saeed-iman-ali-sonya-hussyn-and-feroze-khan-starrer-tich-button-postponed-once-again">Release of Farhan Saeed, Iman Ali, Sonya Hussyn and Feroze Khan starrer Tich Button postponed once again</a></h2>
#  </article>,
#  <article class="story box mb-2 pb-2 border-b border-gray-200" data-id="1717297" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--focus w-1/5 float-right mb-0 ml-3">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717297/long-march-familiar-yet-uncertain" title=""><picture><img alt="Long march, familiar yet uncertain" src="https://i.dawn.com/thumbnail/2022/10/635b45deb5c59.jpg"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-text:3.5-sm:text:3 -->
#  <h2 class="story__title text-3.5 sm:text-3 font-bold font-playfair-display leading-snug" data-id="1717297" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717297/long-march-familiar-yet-uncertain">Long march, familiar yet uncertain
#  </a></h2>
#  </article>,
#  <article class="story box mb-2 pb-2 border-b border-gray-200" data-id="1717352" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--focus w-1/5 float-right mb-0 ml-3">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717352/swat-women-wont-be-duped-by-militants-this-time" title=""><picture><img alt="Swat women won’t be ‘duped’ by militants this time" src="https://i.dawn.com/thumbnail/2022/10/28165514b285b60.jpg?r=165815"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-text:3.5-sm:text:3 -->
#  <h2 class="story__title text-3.5 sm:text-3 font-bold font-playfair-display leading-snug" data-id="1717352" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717352/swat-women-wont-be-duped-by-militants-this-time">Swat women won’t be ‘duped’ by militants this time</a></h2>
#  </article>,
#  <article class="story box mb-2 pb-2" data-id="1717327" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--focus w-1/5 float-right mb-0 ml-3">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717327/zimbabwes-t20-win-against-pakistan-proves-one-thing-the-curse-of-the-bean-is-real" title=""><picture><img alt="Zimbabwe’s T20 win against Pakistan proves one thing — the curse of the Bean is real" src="https://i.dawn.com/thumbnail/2022/10/281130138e16faa.png?r=113051"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-text:3.5-sm:text:3 -->
#  <h2 class="story__title text-3.5 sm:text-3 font-bold font-playfair-display leading-snug" data-id="1717327" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717327/zimbabwes-t20-win-against-pakistan-proves-one-thing-the-curse-of-the-bean-is-real">Zimbabwe’s T20 win against Pakistan proves one thing — the curse of the Bean is real
#  </a></h2>
#  </article>,
#  <article class="story box" data-id="1717157" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--left media--fill sm:w-1/4 w-full mb-0">
#  <div class="media__item"><a href="https://www.dawn.com/news/1717157/an-epidemic-hits-fruit-park-part-2" title=""><picture><img alt="An epidemic hits fruit park - Part 2" src="https://i.dawn.com/medium/2022/10/635a1758e3be2.png"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-text:3.5-sm:text:3 -->
#  <h2 class="story__title text-3.5 sm:text-3 font-bold font-playfair-display leading-tight" data-id="1717157" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717157/an-epidemic-hits-fruit-park-part-2">An epidemic hits fruit park - Part 2
#  </a></h2>
#  <!-- box/excerpt -->
#  <div class="story__excerpt text-3.25 sm:text-3 text-gray-700 font-georgia tracking-wide leading-normal mt-1" dir="auto">Let's find out what Din Din, Dazel and Delma are up to this week.
#
#      </div>
#  </article>,
#  <article class="story box slideshow__slide slideshow__slide--horizontal slideshow__slide--first" data-id="1717170" data-layout="story"> <div class="grid grid-cols sm:grid-cols-2 sm:gap-4 sm:ml-4">
#  <div class="flex flex-col justify-center text-center items-center w-full">
#  <div class="sm:pl-4 sm:pr-8">
#  <div class="text-red-500 font-bold mb-4 text-5">1</div>
#  <!-- box/title title-bold-playfairdisplay-text:5 -->
#  <h2 class="story__title text-5 font-bold font-playfair-display" data-id="1717170" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717170/world-cup-2022-in-thrilling-upset-pakistan-beaten-by-zimbabwe">World Cup 2022: In thrilling upset, Pakistan beaten by Zimbabwe
#  </a></h2>
#  <div class="mx-auto w-1/4 border-b-2 border-gray-200 my-2 sm:my-4"></div>
#  <!-- box/excerpt -->
#  <div class="story__excerpt text-3 font-georgia sm:hidden md:block mb-2" dir="auto">Green Shirts fail to chase down mere 131-run target, now inch towards exit door just two matches into the tournament.
#
#      </div>
#  <div class="flex justify-center font-arial text-2.5 text-gray-400 mb-1 sm:mb-0">
#  <!-- box/label -->
#  <span class="badge inline-flex align-middle" dir="auto" id="sport"><a class="" href="/sport" title="Sport"><span>Sport </span></a></span>
#  <span class="mr-1">,</span>
#  <!-- box/date --><span class="story__time"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2022-10-29T15:36:34+05:00"><span class="timestamp__calendar">29 Oct, 2022</span> <span class="timestamp__time">03:36pm</span></span></span> </div>
#  </div>
#  </div>
#  <div class="">
#  <!-- box/image -->
#  <figure class="media media--fill sm:w-full w-full mb-0" data-focus-x="30.875%" data-focus-y="46.25%">
#  <div class="media__item"><a href="https://www.dawn.com/news/1717170/world-cup-2022-in-thrilling-upset-pakistan-beaten-by-zimbabwe" title=""><picture><img alt="World Cup 2022: In thrilling upset, Pakistan beaten by Zimbabwe" src="https://i.dawn.com/medium/2022/10/272002504c335ff.jpg?r=200319"/></picture></a></div>
#  </figure>
#  </div>
#  </div>
#  </article>,
#  <article class="story box slideshow__slide slideshow__slide--horizontal" data-id="1717298" data-layout="story"> <div class="grid grid-cols sm:grid-cols-2 sm:gap-4 sm:ml-4">
#  <div class="flex flex-col justify-center text-center items-center w-full">
#  <div class="sm:pl-4 sm:pr-8">
#  <div class="text-red-500 font-bold mb-4 text-5">2</div>
#  <!-- box/title title-bold-playfairdisplay-text:5 -->
#  <h2 class="story__title text-5 font-bold font-playfair-display" data-id="1717298" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717298/burnt-bridges">Burnt bridges
#  </a></h2>
#  <div class="mx-auto w-1/4 border-b-2 border-gray-200 my-2 sm:my-4"></div>
#  <!-- box/excerpt -->
#  <div class="story__excerpt text-3 font-georgia sm:hidden md:block mb-2" dir="auto">THE establishment on Thursday reached for the nuclear option as it attempted to reassert itself ahead of the PTI’s...
#
#      </div>
#  <div class="flex justify-center font-arial text-2.5 text-gray-400 mb-1 sm:mb-0">
#  <!-- box/label -->
#  <span class="badge inline-flex align-middle" dir="auto" id="newspaper"><a class="" href="/newspaper" title="Newspaper"><span>Newspaper </span></a></span>
#  <span class="mr-1">,</span>
#  <!-- box/date --><span class="story__time"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2022-10-28T08:51:55+05:00"><span class="timestamp__calendar">28 Oct, 2022</span> <span class="timestamp__time">08:51am</span></span></span> </div>
#  </div>
#  </div>
#  <div class="">
#  </div>
#  </div>
#  </article>,
#  <article class="story box slideshow__slide slideshow__slide--horizontal" data-id="1717163" data-layout="story"> <div class="grid grid-cols sm:grid-cols-2 sm:gap-4 sm:ml-4">
#  <div class="flex flex-col justify-center text-center items-center w-full">
#  <div class="sm:pl-4 sm:pr-8">
#  <div class="text-red-500 font-bold mb-4 text-5">3</div>
#  <!-- box/title title-bold-playfairdisplay-text:5 -->
#  <h2 class="story__title text-5 font-bold font-playfair-display" data-id="1717163" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717163/army-isi-in-unprecedented-presser-question-arshad-sharifs-exit-from-pakistan-point-to-ptis-involvement">Army, ISI in unprecedented presser question Arshad Sharif's exit from Pakistan, point to PTI's involvement
#  </a></h2>
#  <div class="mx-auto w-1/4 border-b-2 border-gray-200 my-2 sm:my-4"></div>
#  <!-- box/excerpt -->
#  <div class="story__excerpt text-3 font-georgia sm:hidden md:block mb-2" dir="auto">Defend the military against PTI's confrontational narrative, say slain journalist was fed "propaganda" on cypher by Imran Khan.
#
#      </div>
#  <div class="flex justify-center font-arial text-2.5 text-gray-400 mb-1 sm:mb-0">
#  <!-- box/label -->
#  <span class="badge inline-flex align-middle" dir="auto" id="pakistan"><a class="" href="/pakistan" title="Pakistan"><span>Pakistan </span></a></span>
#  <span class="mr-1">,</span>
#  <!-- box/date --><span class="story__time"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2022-10-28T08:06:32+05:00"><span class="timestamp__calendar">28 Oct, 2022</span> <span class="timestamp__time">08:06am</span></span></span> </div>
#  </div>
#  </div>
#  <div class="">
#  <!-- box/image -->
#  <figure class="media media--fill sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.dawn.com/news/1717163/army-isi-in-unprecedented-presser-question-arshad-sharifs-exit-from-pakistan-point-to-ptis-involvement" title=""><picture><img alt="Army, ISI in unprecedented presser question Arshad Sharif's exit from Pakistan, point to PTI's involvement" src="https://i.dawn.com/medium/2022/10/635a2b23ef2df.png?r=181158"/></picture></a></div>
#  </figure>
#  </div>
#  </div>
#  </article>,
#  <article class="story box slideshow__slide slideshow__slide--horizontal" data-id="1717178" data-layout="story"> <div class="grid grid-cols sm:grid-cols-2 sm:gap-4 sm:ml-4">
#  <div class="flex flex-col justify-center text-center items-center w-full">
#  <div class="sm:pl-4 sm:pr-8">
#  <div class="text-red-500 font-bold mb-4 text-5">4</div>
#  <!-- box/title title-bold-playfairdisplay-text:5 -->
#  <h2 class="story__title text-5 font-bold font-playfair-display" data-id="1717178" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717178/if-institutions-apolitical-why-hold-a-press-conference-imran-raises-questions-on-ispr-presser">‘If institutions apolitical, why hold a press conference’: Imran raises questions on ISPR presser</a></h2>
#  <div class="mx-auto w-1/4 border-b-2 border-gray-200 my-2 sm:my-4"></div>
#  <!-- box/excerpt -->
#  <div class="story__excerpt text-3 font-georgia sm:hidden md:block mb-2" dir="auto">Says if he starts giving answers, it will cause a lot of damage to the country.
#
#      </div>
#  <div class="flex justify-center font-arial text-2.5 text-gray-400 mb-1 sm:mb-0">
#  <!-- box/label -->
#  <span class="badge inline-flex align-middle" dir="auto" id="pakistan"><a class="" href="/pakistan" title="Pakistan"><span>Pakistan </span></a></span>
#  <span class="mr-1">,</span>
#  <!-- box/date --><span class="story__time"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2022-10-28T00:56:48+05:00"><span class="timestamp__calendar">28 Oct, 2022</span> <span class="timestamp__time">12:56am</span></span></span> </div>
#  </div>
#  </div>
#  <div class="">
#  <!-- box/image -->
#  <figure class="media media--fill sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.dawn.com/news/1717178/if-institutions-apolitical-why-hold-a-press-conference-imran-raises-questions-on-ispr-presser" title=""><picture><img alt="‘If institutions apolitical, why hold a press conference’: Imran raises questions on ISPR presser" src="https://i.dawn.com/medium/2022/10/28005425e5d2bc4.jpg?r=005513"/></picture></a></div>
#  </figure>
#  </div>
#  </div>
#  </article>,
#  <article class="story box slideshow__slide slideshow__slide--horizontal" data-id="1717322" data-layout="story"> <div class="grid grid-cols sm:grid-cols-2 sm:gap-4 sm:ml-4">
#  <div class="flex flex-col justify-center text-center items-center w-full">
#  <div class="sm:pl-4 sm:pr-8">
#  <div class="text-red-500 font-bold mb-4 text-5">5</div>
#  <!-- box/title title-bold-playfairdisplay-text:5 -->
#  <h2 class="story__title text-5 font-bold font-playfair-display" data-id="1717322" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717322/t20-world-cup-babar-defends-move-to-play-extra-pacer-after-zimbabwe-loss">T20 World Cup: Babar defends move to play extra pacer after Zimbabwe loss
#  </a></h2>
#  <div class="mx-auto w-1/4 border-b-2 border-gray-200 my-2 sm:my-4"></div>
#  <!-- box/excerpt -->
#  <div class="story__excerpt text-3 font-georgia sm:hidden md:block mb-2" dir="auto">Shan Masood says Pakistan must believe in World Cup miracle.
#
#      </div>
#  <div class="flex justify-center font-arial text-2.5 text-gray-400 mb-1 sm:mb-0">
#  <!-- box/label -->
#  <span class="badge inline-flex align-middle" dir="auto" id="sport"><a class="" href="/sport" title="Sport"><span>Sport </span></a></span>
#  <span class="mr-1">,</span>
#  <!-- box/date --><span class="story__time"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2022-10-28T14:03:48+05:00"><span class="timestamp__calendar">28 Oct, 2022</span> <span class="timestamp__time">02:03pm</span></span></span> </div>
#  </div>
#  </div>
#  <div class="">
#  <!-- box/image -->
#  <figure class="media media--fill sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.dawn.com/news/1717322/t20-world-cup-babar-defends-move-to-play-extra-pacer-after-zimbabwe-loss" title=""><picture><img alt="T20 World Cup: Babar defends move to play extra pacer after Zimbabwe loss" src="https://i.dawn.com/medium/2022/10/281055178505902.jpg?r=105523"/></picture></a></div>
#  </figure>
#  </div>
#  </div>
#  </article>,
#  <article class="story box mb-2 pb-1 border-b border-gray-200" data-id="1717502" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--fill sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.dawn.com/news/1717502/democratising-appointments" title=""><picture><img alt="Democratising appointments" src="https://i.dawn.com/thumbnail/2022/10/635c99aaf14d2.png"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-py:1-center-text:3.75-sm:text:3.5 -->
#  <h2 class="story__title text-3.75 sm:text-3.5 text-center font-bold font-playfair-display leading-tight py-1" data-id="1717502" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717502/democratising-appointments">Democratising appointments
#  </a></h2>
#  <!-- box/excerpt -->
#  <div class="story__excerpt text-3 sm:text-2.75 text-center font-merriweather tracking-wide mb-1" dir="auto">The seniority versus merit binary is entirely illusory given that the two are not mutually exclusive...
#
#      </div>
#  <!-- box/byline --><div class="text-center" dir="auto"><span class="story__byline text-2.5 text-gray-500 text-center uppercase block" dir="auto"><a class="story__byline__link" href="https://www.dawn.com/authors/8431/mirza-moiz-baig">Mirza Moiz Baig</a></span> </div></article>,
#  <article class="story box mb-1 pb-1 border-b border-gray-200" data-id="1717501" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--left media--focus w-1/4 float-left mb-0 mr-1.25">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717501/where-does-the-money-go" title=""><picture><img alt="Where does the money go?" src="https://i.dawn.com/thumbnail/2022/10/635c9a4b3b105.png"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-py:1-text:3.75-sm:text:3.5 -->
#  <h2 class="story__title text-3.75 sm:text-3.5 font-bold font-playfair-display leading-tight py-1" data-id="1717501" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717501/where-does-the-money-go">Where does the money go?
#  </a></h2>
#  <!-- box/byline --><span class="story__byline text-2.75 sm:text-2.5 text-gray-500 uppercase block" dir="auto"><a class="story__byline__link" href="https://www.dawn.com/authors/9831/zafar-u-ahmed">Zafar U. Ahmed</a></span> </article>,
#  <article class="story box mb-1 pb-1 border-b border-gray-200" data-id="1717500" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--left media--focus w-1/4 float-left mb-0 mr-1.25">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717500/school-after-floods" title=""><picture><img alt="School after floods" src="https://i.dawn.com/thumbnail/2022/10/635c9af999388.png"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-py:1-text:3.75-sm:text:3.5 -->
#  <h2 class="story__title text-3.75 sm:text-3.5 font-bold font-playfair-display leading-tight py-1" data-id="1717500" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717500/school-after-floods">School after floods
#  </a></h2>
#  <!-- box/byline --><span class="story__byline text-2.75 sm:text-2.5 text-gray-500 uppercase block" dir="auto"><a class="story__byline__link" href="https://www.dawn.com/authors/9945/nazir-a-jogezai">Nazir A. Jogezai</a></span> </article>,
#  <article class="story box mb-1 pb-1 border-b border-gray-200" data-id="1717499" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--left media--focus w-1/4 float-left mb-0 mr-1.25">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717499/sunaks-rise-to-pm" title=""><picture><img alt="Sunak’s rise to PM" src="https://i.dawn.com/thumbnail/2022/10/635c97b3a6f7d.jpg"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-py:1-text:3.75-sm:text:3.5 -->
#  <h2 class="story__title text-3.75 sm:text-3.5 font-bold font-playfair-display leading-tight py-1" data-id="1717499" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717499/sunaks-rise-to-pm">Sunak’s rise to PM
#  </a></h2>
#  <!-- box/byline --><span class="story__byline text-2.75 sm:text-2.5 text-gray-500 uppercase block" dir="auto"><a class="story__byline__link" href="https://www.dawn.com/authors/3706/ayesha-ijaz-khan">Ayesha Ijaz Khan</a></span> </article>,
#  <article class="story box mb-1 pb-1" data-id="1717303" data-layout="story">
#  <!-- box/image -->
#  <figure class="media media--left media--focus w-1/4 float-left mb-0 mr-1.25">
#  <div class="media__item media__item--100"><a href="https://www.dawn.com/news/1717303/pakistan-the-way-forward" title=""><picture><img alt="Pakistan: the way forward?" src="https://i.dawn.com/thumbnail/2022/10/635b48beb2b4e.jpg"/></picture></a></div>
#  </figure>
#  <!-- box/title bold-playfairdisplay-py:1-text:3.75-sm:text:3.5 -->
#  <h2 class="story__title text-3.75 sm:text-3.5 font-bold font-playfair-display leading-tight py-1" data-id="1717303" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717303/pakistan-the-way-forward">Pakistan: the way forward?
#  </a></h2>
#  <!-- box/byline --><span class="story__byline text-2.75 sm:text-2.5 text-gray-500 uppercase block" dir="auto"><a class="story__byline__link" href="https://www.dawn.com/authors/568/faisal-bari">Faisal Bari</a></span> </article>,
#  <article class="story box mb-3 pb-2 border-b border-gray-200" data-id="1717505" data-layout="story">
#  <!-- box/title bold-playfairdisplay-pb:1-italic-text:3.5 -->
#  <h2 class="story__title text-3.5 italic font-bold font-playfair-display leading-tight pb-1" data-id="1717505" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717505/reviving-cpec">Reviving CPEC
#  </a></h2>
#  <!-- box/excerpt -->
#  <div class="story__excerpt text-3.25 font-georgia tracking-wide" dir="auto">PRIME Minister Shehbaz Sharif’s first official trip to China, that begins early next week, will focus on the...
#
#      </div>
#  </article>,
#  <article class="story box mb-3 pb-2 border-b border-gray-200" data-id="1717504" data-layout="story">
#  <!-- box/title bold-playfairdisplay-pb:1-italic-text:3.5 -->
#  <h2 class="story__title text-3.5 italic font-bold font-playfair-display leading-tight pb-1" data-id="1717504" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717504/hollow-sabre-rattling">Hollow sabre-rattling
#  </a></h2>
#  <!-- box/excerpt -->
#  <div class="story__excerpt text-3.25 font-georgia tracking-wide" dir="auto">RESPONSIBLE officials of state should know better than to make incendiary claims that have the potential to further...
#
#      </div>
#  </article>,
#  <article class="story box mb-3 pb-2 border-b border-gray-200" data-id="1717503" data-layout="story">
#  <!-- box/title bold-playfairdisplay-pb:1-italic-text:3.5 -->
#  <h2 class="story__title text-3.5 italic font-bold font-playfair-display leading-tight pb-1" data-id="1717503" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717503/renewed-resistance">Renewed resistance
#  </a></h2>
#  <!-- box/excerpt -->
#  <div class="story__excerpt text-3.25 font-georgia tracking-wide" dir="auto">ONCE again, Israel is on the rampage in the occupied territories. Whilst most incursions over the recent past have...
#
#      </div>
#  </article>,
#  <article class="story box" data-id="1717484" data-layout="slideshow">
#  <!-- box/image -->
#  <figure class="media media--fill sm:w-full w-full mb-0">
#  <div class="media__item"><a href="https://www.dawn.com/news/1717484/cartoon-29-october-2022" title=""><picture><img alt="Cartoon: 29 October, 2022" src="https://i.dawn.com/medium/2022/10/635c5820aab44.jpg"/></picture></a></div>
#  </figure>
#  </article>,
#  <article class="story box" data-id="1717303" data-layout="story">
#  <!-- box/title bold-merriweather-pb:1.25-text:3 -->
#  <h2 class="story__title text-3 font-bold font-merriweather leading-tight pb-1.25" data-id="1717303" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717303/pakistan-the-way-forward">Pakistan: the way forward?
#  </a></h2>
#  <!-- box/excerpt -->
# ...
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717457" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717457" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717457/logistics-firm-unsl-to-migrate-from-gem-to-psx-main-board">Logistics firm UNSL to migrate from GEM to PSX main board</a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717450" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717450" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717450/all-to-play-for-after-australia-england-clash-washed-out">All to play for after Australia, England clash washed out
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717445" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717445" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717445/ronaldo-scores-as-united-seal-europa-knockout-spot">Ronaldo scores as United seal Europa knockout spot
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717444" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717444" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717444/northern-stutter-against-sp-haseeb-hits-ton-for-balochistan">Northern stutter against SP; Haseeb hits ton for Balochistan
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717452" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717452" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717452/demoralised-pakistan-must-believe-in-miracle-shan">Demoralised Pakistan must believe in miracle: Shan
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717451" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717451" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717451/babar-azam-slammed-for-poor-captaincy">Babar Azam slammed for poor captaincy</a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717505" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717505" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717505/reviving-cpec">Reviving CPEC
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717504" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717504" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717504/hollow-sabre-rattling">Hollow sabre-rattling
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717503" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717503" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717503/renewed-resistance">Renewed resistance
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717298" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717298" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717298/burnt-bridges">Burnt bridges
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717296" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717296" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717296/gas-management">Gas management
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717502" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717502" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717502/democratising-appointments">Democratising appointments
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717501" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717501" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717501/where-does-the-money-go">Where does the money go?
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717500" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717500" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717500/school-after-floods">School after floods
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717499" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717499" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717499/sunaks-rise-to-pm">Sunak’s rise to PM
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717303" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717303" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717303/pakistan-the-way-forward">Pakistan: the way forward?
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717478" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717478" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717478/new-york-police-say-extremists-could-pose-threat-as-mid-term-election-nears">New York police say extremists could pose threat as mid-term election nears
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717476" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717476" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717476/defiant-iranians-hit-the-streets-again-to-protest-crackdown">Defiant Iranians hit the streets again to protest crackdown
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717483" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717483" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717483/qatar-protests-to-germany-over-ministers-world-cup-comments">Qatar protests to Germany over minister’s World Cup comments
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717482" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717482" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717482/for-twitter-boss-musk-now-comes-the-hard-part">For Twitter boss Musk, now comes the hard part
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717481" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717481" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717481/unprecedented-power-cuts-planned-in-kyiv">‘Unprecedented’ power cuts planned in Kyiv
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1660293" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1660293" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1660293/epicurious-the-gingerbread-village">EPICURIOUS: THE GINGERBREAD VILLAGE
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1660589" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1660589" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1660589/golf-pakistans-soaring-eagles">GOLF: PAKISTAN’S SOARING EAGLES
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1660591" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1660591" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1660591/society-inspiring-inclusivity-one-post-at-a-time">SOCIETY: INSPIRING INCLUSIVITY, ONE POST AT A TIME
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1660694" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1660694" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1660694/a-battle-of-the-sexes-amid-scalpels-and-sutures">A BATTLE OF THE SEXES AMID SCALPELS AND SUTURES
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1564771" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1564771" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1564771/health-voices-from-the-front-lines">HEALTH: VOICES FROM THE FRONT LINES
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1716430" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1716430" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1716430/non-fiction-the-joy-of-sharing-food">NON-FICTION: THE JOY OF SHARING FOOD
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1716429" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1716429" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1716429/essay-a-5000-year-history-of-writers-block">ESSAY: A 5,000-YEAR HISTORY OF WRITER’S BLOCK
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1716427" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1716427" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1716427/non-fiction-empires-brutal-legacies">NON-FICTION: EMPIRE’S BRUTAL LEGACIES
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1716414" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1716414" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1716414/fiction-schiele-and-his-muses">FICTION: SCHIELE AND HIS MUSES
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1715315" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1715315" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1715315/non-fiction-the-lives-of-others">NON-FICTION: THE LIVES OF OTHERS
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1716669" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1716669" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1716669/looking-for-a-new-delivery-model">Looking for a new delivery model
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1716668" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1716668" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1716668/daronomics-good-or-bad-for-the-economy">Daronomics — good or bad for the economy?
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1716666" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1716666" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1716666/recurrent-food-crisis">Recurrent food crisis
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1716665" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1716665" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1716665/wheats-political-blame-game">Wheat’s political blame game
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1716664" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1716664" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1716664/kse-100-share-index-fluctuations">KSE 100-share index fluctuations
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717541" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717541" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717541/seven-steps-to-unlock-your-creativity">Seven steps to unlock your creativity
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717540" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717540" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717540/mailbox">Mailbox
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717538" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717538" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717538/poets-corner">Poet's Corner
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717536" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717536" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717536/wonder-craft-miniature-paper-fan">Wonder Craft: Miniature paper fan
#  </a></h2>
#  </article>,
#  <article class="story box border-b border-gray-200" data-id="1717535" data-layout="story">
#  <!-- box/title normal-text:3-py:2 -->
#  <h2 class="story__title text-3 font-normal py-2" data-id="1717535" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717535/the-weekly-weird">The weekly weird
#  </a></h2>
#  </article>]

# %%
titles = []
links = []
images = []
author_names = []
published_time = []
paragraph = []

# %%
data[0]
# Out:
# <article class="story box mb-2 pb-1" data-id="1717321" data-layout="story">
# <!-- box/label -->
# <span class="badge inline-flex text-3 font-normal rounded theme theme-default theme--live align-middle" dir="auto" id="live"><span>Live </span></span>
# <!-- box/title title-bold-playfairdisplay-pb:1-text:5 -->
# <h2 class="story__title text-5 font-bold font-playfair-display leading-tight pb-1" data-id="1717321" data-layout="story" dir="auto"><a class="story__link" href="https://www.dawn.com/news/1717321/long-march-day-2-marriyum-rules-out-negotiations-with-imran-khan">Long march day 2: Marriyum rules out negotiations with Imran Khan</a></h2>
# <!-- box/image -->
# <figure class="media media--fill sm:w-full w-full mb-1">
# <div class="media__item"><a href="https://www.dawn.com/news/1717321/long-march-day-2-marriyum-rules-out-negotiations-with-imran-khan" title=""><picture><img alt="Long march day 2: Marriyum rules out negotiations with Imran Khan" src="https://i.dawn.com/medium/2022/10/291627156b6aa44.png?r=163019"/></picture></a></div>
# </figure>
# <!-- box/excerpt -->
# <div class="story__excerpt text-3 font-georgia mb-1.5" dir="auto">March resumes from Lahore's Shahdara and will make a pit stop in Kamoke at the end of the day.
#
#     </div>
# <!-- box/date --><span class="story__time text-2.5 text-gray-400 font-arial block"><span class="timestamp--label">Updated</span> <span class="timestamp--time timeago" title="2022-10-29T16:30:54+05:00"><span class="timestamp__calendar">29 Oct, 2022</span> <span class="timestamp__time">04:30pm</span></span></span> </article>

# %%
anchor = data[0].find('a')

# %%
anchor
# Out:
# <a class="story__link" href="https://www.dawn.com/news/1717321/long-march-day-2-marriyum-rules-out-negotiations-with-imran-khan">Long march day 2: Marriyum rules out negotiations with Imran Khan</a>

# %%
anchor.text
# Out:
# 'Long march day 2: Marriyum rules out negotiations with Imran Khan'

# %%
anchor['href']
# Out:
# 'https://www.dawn.com/news/1717321/long-march-day-2-marriyum-rules-out-negotiations-with-imran-khan'

# %%
data[0].find('img')
# Out:
# <img alt="Long march day 2: Marriyum rules out negotiations with Imran Khan" src="https://i.dawn.com/medium/2022/10/291627156b6aa44.png?r=163019"/>

# %%
data[0].find('img')['src']
# Out:
# 'https://i.dawn.com/medium/2022/10/291627156b6aa44.png?r=163019'

# %%
for i in data:
    anchor = i.find('a')
    img = i.find('img')
    titles.append(anchor.text)
    links.append(anchor['href'])
    if img:
        images.append(img['src'])
    else:
        images.append(' ')
    
    author = i.find('span','story__byline').a.text if i.find('span','story__byline') else ''
    author_names.append(author)
    
    date = i.find('span', class_ = 'timestamp--time  timeago').text if i.find('span', class_ = 'timestamp--time  timeago') else '**'
    published_time.append(date)
    
    para = i.find('div', class_ = 'story__excerpt').text if i.find('div', class_ = 'story__excerpt') else ''
    paragraph.append(para)

# %%
len(titles)
# Out:
# 177

# %%
len(links)
# Out:
# 177

# %%
len(images)
# Out:
# 177

# %%
dawn_df = pd.DataFrame({'Titles':titles,'Author Names':author_names,'Published Time':published_time,'First Paragraph':paragraph,'Links':links,'Images':images})

# %%
dawn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Titles           177 non-null    object
#  1   Author Names     177 non-null    object
#  2   Published Time   177 non-null    object
#  3   First Paragraph  177 non-null    object
#  4   Links            177 non-null    object
#  5   Images           177 non-null    object
# dtypes: object(6)
# memory usage: 8.4+ KB

# %%
import numpy as np
df = dawn_df.replace(r'^s*$', np.nan, regex=True) # replacing empty cells with NaN values

# %%
df
# Out:
#                                                 Titles Author Names  \
# 0    Long march day 2: Marriyum rules out negotiati...          NaN
# 1    Pakistani prisoner Saifullah Paracha released ...          NaN
# 2    2 army soldiers martyred in exchange of fire w...          NaN
# 3       PTI terminates Faisal Vawda’s party membership          NaN
# 4    Police round up 34 suspects for allegedly lync...          NaN
# ..                                                 ...          ...
# 172            Seven steps to unlock your creativity\n          NaN
# 173                                          Mailbox\n          NaN
# 174                                    Poet's Corner\n          NaN
# 175                Wonder Craft: Miniature paper fan\n          NaN
# 176                                 The weekly weird\n          NaN
#
#     Published Time                                    First Paragraph  \
# 0               **  March resumes from Lahore's Shahdara and will ...
# 1               **  Paracha repatriated to Pakistan after "extensi...
# 2               **  ISPR says sanitisation of the area is being ca...
# 3               **  Termination follows show-cause notice issued t...
# 4               **  Vigilante mob lync­hed two men and torched the...
# ..             ...                                                ...
# 172             **                                                NaN
# 173             **                                                NaN
# 174             **                                                NaN
# 175             **                                                NaN
# 176             **                                                NaN
#
#                                                  Links  \
# 0    https://www.dawn.com/news/1717321/long-march-d...
# 1    https://www.dawn.com/news/1717539/pakistani-pr...
# 2    https://www.dawn.com/news/1717558/2-army-soldi...
# 3    https://www.dawn.com/news/1717533/pti-terminat...
# 4    https://www.dawn.com/news/1717544/police-round...
# ..                                                 ...
# 172  https://www.dawn.com/news/1717541/seven-steps-...
# 173          https://www.dawn.com/news/1717540/mailbox
# 174     https://www.dawn.com/news/1717538/poets-corner
# 175  https://www.dawn.com/news/1717536/wonder-craft...
# 176  https://www.dawn.com/news/1717535/the-weekly-w...
#
#                                                 Images
# 0    https://i.dawn.com/medium/2022/10/291627156b6a...
# 1    https://i.dawn.com/medium/2022/10/29123714381f...
# 2
# 3    https://i.dawn.com/medium/2022/10/29121303fcbf...
# 4
# ..                                                 ...
# 172
# 173
# 174
# 175
# 176
#
# [177 rows x 6 columns]

# %%
df.shape
# Out:
# (177, 6)

# %%
df.to_csv('E:/dawn_articles.csv')

# %% [markdown]
# # 2 - Top Science Fiction Movies

# %%
webpage = requests.get('https://www.imdb.com/search/title/?genres=sci-fi&explore=title_type,genres&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=3396781f-d87f-4fac-8694-c56ce6f490fe&pf_rd_r=8J8TDTSFDKRN3C9SVGCP&pf_rd_s=center-1&pf_rd_t=15051&pf_rd_i=genre&ref_=ft_gnr_pr1_i_2').text

# %%
soup=BeautifulSoup(webpage,'html.parser')

# %%
movie_names = []
year = []
genre = []
rating = []

# %%
movies_data = soup.find_all('div', class_ = 'lister-item mode-advanced')

# %%
for i in movies_data:
    name = i.h3.a.text
    movie_names.append(name)

# %%
len(movie_names)
# Out:
# 50

# %%
for i in movies_data:
    yr = i.h3.find('span', class_= 'lister-item-year text-muted unbold').text.replace('(','').replace(')','')
    year.append(yr)

# %%
len(year)
# Out:
# 50

# %%
for i in movies_data:
    gn = i.p.find('span', class_ = 'genre').text.replace('\n','')
    genre.append(gn)

# %%
len(genre)
# Out:
# 50

# %%
for i in movies_data:
    rt = i.find('div', class_= 'inline-block ratings-imdb-rating').text.replace('\n','') if i.find('div', class_= 'inline-block ratings-imdb-rating') else '^^'
    rating.append(rt)

# %%
len(rating)
# Out:
# 50

# %%
movies_df = pd.DataFrame({'Name of Movie':movie_names,'Year of Release':year,'Genre':genre,'Rating':rating})

# %%
movies_df
# Out:
#                                   Name of Movie Year of Release  \
# 0                                    Black Adam            2022
# 1                                         Andor          2022–
# 2                         American Horror Story          2011–
# 3                     She-Hulk: Attorney at Law            2022
# 4                                The Peripheral          2022–
# 5                           The Handmaid's Tale          2017–
# 6                               Stranger Things          2016–
# 7                                Rick and Morty          2013–
# 8                Black Panther: Wakanda Forever            2022
# 9                                      The Boys          2019–
# 10                                          See       2019–2022
# 11            Everything Everywhere All at Once            2022
# 12                       Thor: Love and Thunder            2022
# 13                                   Doctor Who          2005–
# 14                                  The Sandman          2022–
# 15                                         Nope            2022
# 16                     Avatar: The Way of Water            2022
# 17                                        M3GAN            2023
# 18                       Cyberpunk: Edgerunners          2022–
# 19                                 Quantum Leap          2022–
# 20                                    Severance          2022–
# 21                  The Super Mario Bros. Movie            2023
# 22                                     Avenue 5          2020–
# 23                                    Westworld          2016–
# 24                                 The Munsters            2022
# 25                      DC League of Super-Pets            2022
# 26                                 Black Mirror       2011–2019
# 27                                    Daredevil       2015–2018
# 28                                         Prey          I 2022
# 29                              The Mandalorian          2019–
# 30                      Jurassic World Dominion            2022
# 31                      Spider-Man: No Way Home            2021
# 32                                  The X Files       1993–2018
# 33                            Significant Other            2022
# 34                                       Avatar            2009
# 35                                         Lost       2004–2010
# 36                                       Vesper            2022
# 37                                  The Orville          2017–
# 38                                      La Brea          2021–
# 39                               Dune: Part One            2021
# 40                                       Titans        I 2018–
# 41                                    The Flash       2014–2023
# 42                                 Interstellar            2014
# 43                                     Manifest          2018–
# 44                                         Dark       2017–2020
# 45                         The Umbrella Academy       2019–2023
# 46                                    Rogue One            2016
# 47                            War of the Worlds          2019–
# 48  Doctor Strange in the Multiverse of Madness            2022
# 49                                 Ghostbusters            1984
#
#                                        Genre Rating
# 0     Action, Adventure, Fantasy                7.1
# 1       Action, Adventure, Drama                8.2
# 2          Drama, Horror, Sci-Fi                8.0
# 3      Action, Adventure, Comedy                5.1
# 4         Drama, Mystery, Sci-Fi                8.4
# 5        Drama, Sci-Fi, Thriller                8.4
# 6         Drama, Fantasy, Horror                8.7
# 7   Animation, Adventure, Comedy                9.2
# 8       Action, Adventure, Drama                 ^^
# 9          Action, Comedy, Crime                8.7
# 10         Action, Drama, Sci-Fi                7.6
# 11     Action, Adventure, Comedy                8.1
# 12     Action, Adventure, Comedy                6.4
# 13      Adventure, Drama, Sci-Fi                8.6
# 14        Drama, Fantasy, Horror                7.7
# 15       Horror, Mystery, Sci-Fi                6.9
# 16    Action, Adventure, Fantasy                 ^^
# 17      Horror, Sci-Fi, Thriller                 ^^
# 18  Animation, Action, Adventure                8.4
# 19        Drama, Mystery, Sci-Fi                5.4
# 20        Drama, Mystery, Sci-Fi                8.7
# 21  Animation, Adventure, Comedy                 ^^
# 22                Comedy, Sci-Fi                6.6
# 23        Drama, Mystery, Sci-Fi                8.5
# 24       Comedy, Family, Fantasy                4.6
# 25  Animation, Action, Adventure                7.3
# 26        Drama, Mystery, Sci-Fi                8.8
# 27          Action, Crime, Drama                8.6
# 28      Action, Adventure, Drama                7.2
# 29    Action, Adventure, Fantasy                8.7
# 30     Action, Adventure, Sci-Fi                5.7
# 31    Action, Adventure, Fantasy                8.3
# 32         Crime, Drama, Mystery                8.6
# 33        Drama, Mystery, Sci-Fi                5.7
# 34    Action, Adventure, Fantasy                7.8
# 35     Adventure, Drama, Fantasy                8.3
# 36      Adventure, Drama, Sci-Fi                6.1
# 37      Adventure, Comedy, Drama                8.0
# 38        Drama, Mystery, Sci-Fi                5.7
# 39      Action, Adventure, Drama                8.0
# 40      Action, Adventure, Crime                7.6
# 41      Action, Adventure, Drama                7.6
# 42      Adventure, Drama, Sci-Fi                8.6
# 43        Drama, Mystery, Sci-Fi                7.1
# 44         Crime, Drama, Mystery                8.7
# 45     Action, Adventure, Comedy                7.9
# 46     Action, Adventure, Sci-Fi                7.8
# 47        Drama, Mystery, Sci-Fi                6.4
# 48    Action, Adventure, Fantasy                6.9
# 49       Action, Comedy, Fantasy                7.8

# %%
movies_df.to_csv('E:/top_Sci_movies.csv')

# %% [markdown]
# # 3 - Web Scrapping From Multiple Webpages

# %%
import numpy as np
from time import sleep
from random import randint

# %%
movie_names = []
year = []
genre = []
rating = []

# %%
pages = np.arange(1,1000,50)

# %%
for page in pages:
    page = requests.get('https://www.imdb.com/search/title/?groups=top_1000&sort=user_rating,desc&start='+str(page)+'&ref_=adv_nxt')
    soup = BeautifulSoup(page.text, 'html.parser')
    movie_data = soup.find_all('div', class_ = 'lister-item mode-advanced')
    sleep(randint(2,8))
    for i in movie_data:
        name = i.h3.a.text
        movie_names.append(name)
        
        yr = i.h3.find('span', class_= 'lister-item-year text-muted unbold').text.replace('(','').replace(')','')
        year.append(yr)
        
        gn = i.p.find('span', class_ = 'genre').text.replace('\n','')
        genre.append(gn)
        
        rt = i.find('div', class_= 'inline-block ratings-imdb-rating').text.replace('\n','') if i.find('div', class_= 'inline-block ratings-imdb-rating') else '^^'
        rating.append(rt)

# %%
movies_df = pd.DataFrame({'Name of Movie':movie_names,'Year of Release':year,'Genre':genre,'Rating':rating})

# %%
movies_df
# Out:
#                                      Name of Movie Year of Release  \
# 0                         The Shawshank Redemption            1994
# 1                                          Kantara            2022
# 2                                    The Godfather            1972
# 3                                  The Dark Knight            2008
# 4    The Lord of the Rings: The Return of the King            2003
# ..                                             ...             ...
# 995                                        Sabrina            1954
# 996                          From Here to Eternity            1953
# 997                Snow White and the Seven Dwarfs            1937
# 998                                   The 39 Steps            1935
# 999                              The Invisible Man            1933
#
#                                         Genre Rating
# 0                           Drama                9.3
# 1        Action, Adventure, Drama                9.2
# 2                    Crime, Drama                9.2
# 3            Action, Crime, Drama                9.0
# 4        Action, Adventure, Drama                9.0
# ..                                        ...    ...
# 995        Comedy, Drama, Romance                7.6
# 996           Drama, Romance, War                7.6
# 997  Animation, Adventure, Family                7.6
# 998      Crime, Mystery, Thriller                7.6
# 999                Horror, Sci-Fi                7.6
#
# [1000 rows x 4 columns]

# %%
movies_df.to_csv('E:/top_1000_movies.csv')

# %% [markdown]
# # 4 - Using API

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 100.683,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 16819},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 100.7,
#   'poster_path': '/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 22545},
#  {'adult': False,
#   'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg',
#   'genre_ids': [18, 80],
#   'id': 240,
#   'original_language': 'en',
#   'original_title': 'The Godfather Part II',
#   'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.',
#   'popularity': 60.113,
#   'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg',
#   'release_date': '1974-12-20',
#   'title': 'The Godfather Part II',
#   'video': False,
#   'vote_average': 8.6,
#   'vote_count': 10192},
#  {'adult': False,
#   'backdrop_path': '/zb6fM1CX41D9rF9hdgclu0peUmy.jpg',
#   'genre_ids': [18, 36, 10752],
#   'id': 424,
#   'original_language': 'en',
#   'original_title': "Schindler's List",
#   'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.',
#   'popularity': 51.331,
#   'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg',
#   'release_date': '1993-12-15',
#   'title': "Schindler's List",
#   'video': False,
#   'vote_average': 8.6,
#   'vote_count': 13384},
#  {'adult': False,
#   'backdrop_path': '/vI3aUGTuRRdM7J78KIdW98LdxE5.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 19404,
#   'original_language': 'hi',
#   'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#   'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#   'popularity': 29.773,
#   'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#   'release_date': '1995-10-19',
#   'title': 'Dilwale Dulhania Le Jayenge',
#   'video': False,
#   'vote_average': 8.6,
#   'vote_count': 3928},
#  {'adult': False,
#   'backdrop_path': '/Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg',
#   'genre_ids': [16, 10751, 14],
#   'id': 129,
#   'original_language': 'ja',
#   'original_title': '千と千尋の神隠し',
#   'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.',
#   'popularity': 94.229,
#   'poster_path': '/39wmItIWsg5sZMyRUHLkWBcuVCM.jpg',
#   'release_date': '2001-07-20',
#   'title': 'Spirited Away',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 13479},
#  {'adult': False,
#   'backdrop_path': '/bxSBOAD8AuMHYMdW3jso9npAkgt.jpg',
#   'genre_ids': [10751, 18],
#   'id': 667257,
#   'original_language': 'es',
#   'original_title': 'Cosas imposibles',
#   'overview': 'Matilde is a woman who, after the death of her husband - a man who constantly abused her - finds her new best friend in Miguel, her young, insecure, disoriented and even dealer neighbor',
#   'popularity': 10.388,
#   'poster_path': '/t2Ew8NZ8Ci2kqmoecZUNQUFDJnQ.jpg',
#   'release_date': '2021-06-17',
#   'title': 'Impossible Things',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 271},
#  {'adult': False,
#   'backdrop_path': '/qqHQsStV6exghCM7zbObuYBiYxw.jpg',
#   'genre_ids': [18],
#   'id': 389,
#   'original_language': 'en',
#   'original_title': '12 Angry Men',
#   'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.",
#   'popularity': 30.666,
#   'poster_path': '/ppd84D2i9W8jXmsyInGyihiSyqz.jpg',
#   'release_date': '1957-04-10',
#   'title': '12 Angry Men',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 6754},
#  {'adult': False,
#   'backdrop_path': '/mMtUybQ6hL24FXo0F3Z4j2KG7kZ.jpg',
#   'genre_ids': [10749, 16, 18],
#   'id': 372058,
#   'original_language': 'ja',
#   'original_title': '君の名は。',
#   'overview': 'High schoolers Mitsuha and Taki are complete strangers living separate lives. But one night, they suddenly switch places. Mitsuha wakes up in Taki’s body, and he in hers. This bizarre occurrence continues to happen randomly, and the two must adjust their lives around each other.',
#   'popularity': 139.749,
#   'poster_path': '/q719jXXEzOoYaps6babgKnONONX.jpg',
#   'release_date': '2016-08-26',
#   'title': 'Your Name.',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 9181},
#  {'adult': False,
#   'backdrop_path': '/TU9NIjwzjoKPwQHoHshkFcQUCG.jpg',
#   'genre_ids': [35, 53, 18],
#   'id': 496243,
#   'original_language': 'ko',
#   'original_title': '기생충',
#   'overview': "All unemployed, Ki-taek's family takes peculiar interest in the wealthy and glamorous Parks for their livelihood until they get entangled in an unexpected incident.",
#   'popularity': 71.995,
#   'poster_path': '/7IiTTgloJzvGI1TAYymCfbfl3vT.jpg',
#   'release_date': '2019-05-30',
#   'title': 'Parasite',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 14612},
#  {'adult': False,
#   'backdrop_path': '/l6hQWH9eDksNJNiXWYRkWqikOdu.jpg',
#   'genre_ids': [14, 18, 80],
#   'id': 497,
#   'original_language': 'en',
#   'original_title': 'The Green Mile',
#   'overview': "A supernatural tale set on death row in a Southern prison, where gentle giant John Coffey possesses the mysterious power to heal people's ailments. When the cell block's head guard, Paul Edgecomb, recognizes Coffey's miraculous gift, he tries desperately to help stave off the condemned man's execution.",
#   'popularity': 85.762,
#   'poster_path': '/velWPhVMQeQKcxggNEU8YmIo52R.jpg',
#   'release_date': '1999-12-10',
#   'title': 'The Green Mile',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 14552},
#  {'adult': False,
#   'backdrop_path': '/3RMLbSEXOn1CzLoNT7xFeLfdxhq.jpg',
#   'genre_ids': [10749, 16],
#   'id': 372754,
#   'original_language': 'ja',
#   'original_title': '同級生',
#   'overview': 'Rihito Sajo, an honor student with a perfect score on the entrance exam and Hikaru Kusakabe, in a band and popular among girls, would have never crossed paths. Until one day they started talking at the practice for their school’s upcoming chorus festival. After school, the two meet regularly, as Hikaru helps Rihito to improve his singing skills. While they listen to each other’s voice and harmonize, their hearts start to beat together.',
#   'popularity': 14.517,
#   'poster_path': '/cIfRCA5wEvj9tApca4UDUagQEiM.jpg',
#   'release_date': '2016-02-20',
#   'title': 'Dou kyu sei – Classmates',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 257},
#  {'adult': False,
#   'backdrop_path': '/jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg',
#   'genre_ids': [10749],
#   'id': 724089,
#   'original_language': 'en',
#   'original_title': "Gabriel's Inferno: Part II",
#   'overview': "Professor Gabriel Emerson finally learns the truth about Julia Mitchell's identity, but his realization comes a moment too late. Julia is done waiting for the well-respected Dante specialist to remember her and wants nothing more to do with him. Can Gabriel win back her heart before she finds love in another's arms?",
#   'popularity': 14.454,
#   'poster_path': '/x5o8cLZfEXMoZczTYWLrUo1P7UJ.jpg',
#   'release_date': '2020-07-31',
#   'title': "Gabriel's Inferno: Part II",
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 1440},
#  {'adult': False,
#   'backdrop_path': '/w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg',
#   'genre_ids': [10749],
#   'id': 696374,
#   'original_language': 'en',
#   'original_title': "Gabriel's Inferno",
#   'overview': "An intriguing and sinful exploration of seduction, forbidden love, and redemption, Gabriel's Inferno is a captivating and wildly passionate tale of one man's escape from his own personal hell as he tries to earn the impossible--forgiveness and love.",
#   'popularity': 11.839,
#   'poster_path': '/oyG9TL7FcRP4EZ9Vid6uKzwdndz.jpg',
#   'release_date': '2020-05-29',
#   'title': "Gabriel's Inferno",
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 2293},
#  {'adult': False,
#   'backdrop_path': '/nMKdUUepR0i5zn0y1T4CsSB5chy.jpg',
#   'genre_ids': [18, 28, 80, 53],
#   'id': 155,
#   'original_language': 'en',
#   'original_title': 'The Dark Knight',
#   'overview': 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#   'popularity': 79.676,
#   'poster_path': '/qJ2tW6WMUDux911r6m7haRef0WH.jpg',
#   'release_date': '2008-07-14',
#   'title': 'The Dark Knight',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 28479},
#  {'adult': False,
#   'backdrop_path': '/v5CEt88iDsuoMaW1Q5Msu9UZdEt.jpg',
#   'genre_ids': [10749, 18],
#   'id': 730154,
#   'original_language': 'ja',
#   'original_title': 'きみの瞳が問いかけている',
#   'overview': "A tragic accident lead to Kaori's blindness, but she clings to life and the smaller pleasures it can still afford her. She meets Rui and begins to talk to him. Rui was once a promising kickboxer, but something happened in his past. Kaori's smile brings out a change in Rui. However, the two are connected in more than one way. Rui attempts to do what is right.",
#   'popularity': 42.993,
#   'poster_path': '/cVn8E3Fxbi8HzYYtaSfsblYC4gl.jpg',
#   'release_date': '2020-10-23',
#   'title': 'Your Eyes Tell',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 357},
#  {'adult': False,
#   'backdrop_path': '/suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg',
#   'genre_ids': [53, 80],
#   'id': 680,
#   'original_language': 'en',
#   'original_title': 'Pulp Fiction',
#   'overview': "A burger-loving hit man, his philosophical partner, a drug-addled gangster's moll and a washed-up boxer converge in this sprawling, comedic crime caper. Their adventures unfurl in three stories that ingeniously trip back and forth in time.",
#   'popularity': 67.033,
#   'poster_path': '/fIE3lAGcZDV1G6XM5KmuWnNsPp1.jpg',
#   'release_date': '1994-09-10',
#   'title': 'Pulp Fiction',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 23968},
#  {'adult': False,
#   'backdrop_path': '/x4biAVdPVCghBlsVIzB6NmbghIz.jpg',
#   'genre_ids': [37],
#   'id': 429,
#   'original_language': 'it',
#   'original_title': 'Il buono, il brutto, il cattivo',
#   'overview': 'While the Civil War rages on between the Union and the Confederacy, three men – a quiet loner, a ruthless hitman, and a Mexican bandit – comb the American Southwest in search of a strongbox containing $200,000 in stolen gold.',
#   'popularity': 62.255,
#   'poster_path': '/bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg',
#   'release_date': '1966-12-23',
#   'title': 'The Good, the Bad and the Ugly',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 6934},
#  {'adult': False,
#   'backdrop_path': '/aQ7444JX7gefPhGJTlvilj3zG2S.jpg',
#   'genre_ids': [10402],
#   'id': 553512,
#   'original_language': 'ko',
#   'original_title': '번 더 스테이지: 더 무비',
#   'overview': 'A documentary following the worldwide famous music group BTS, as they tour the world and share their experience along with their beloved band friends and fans.',
#   'popularity': 15.292,
#   'poster_path': '/pJKy1yvnKh8UjcuYeG3Rt35xHFA.jpg',
#   'release_date': '2018-11-15',
#   'title': 'Burn the Stage: The Movie',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 370},
#  {'adult': False,
#   'backdrop_path': '/lXhgCODAbBXL5buk9yEmTpOoOgR.jpg',
#   'genre_ids': [12, 14, 28],
#   'id': 122,
#   'original_language': 'en',
#   'original_title': 'The Lord of the Rings: The Return of the King',
#   'overview': "Aragorn is revealed as the heir to the ancient kings as he, Gandalf and the other members of the broken fellowship struggle to save Gondor from Sauron's forces. Meanwhile, Frodo and Sam take the ring closer to the heart of Mordor, the dark lord's realm.",
#   'popularity': 130.447,
#   'poster_path': '/rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg',
#   'release_date': '2003-12-01',
#   'title': 'The Lord of the Rings: The Return of the King',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 20429}]

# %%
pd.DataFrame(response.json()['results']).head()
# Out:
#    adult                     backdrop_path        genre_ids     id  \
# 0  False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg         [18, 80]    238
# 1  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg         [18, 80]    278
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]    240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]    424
# 4  False  /vI3aUGTuRRdM7J78KIdW98LdxE5.jpg  [35, 18, 10749]  19404
#
#   original_language                original_title  \
# 0                en                 The Godfather
# 1                en      The Shawshank Redemption
# 2                en         The Godfather Part II
# 3                en              Schindler's List
# 4                hi  दिलवाले दुल्हनिया ले जायेंगे
#
#                                             overview  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...     100.683
# 1  Framed in the 1940s for the double murder of h...     100.700
# 2  In the continuing saga of the Corleone crime f...      60.113
# 3  The true story of how businessman Oskar Schind...      51.331
# 4  Raj is a rich, carefree, happy-go-lucky second...      29.773
#
#                         poster_path release_date                        title  \
# 0  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14                The Godfather
# 1  /q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg   1994-09-23     The Shawshank Redemption
# 2  /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20        The Godfather Part II
# 3  /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15             Schindler's List
# 4  /2CAL2433ZeIihfX1Hb2139CX0pW.jpg   1995-10-19  Dilwale Dulhania Le Jayenge
#
#    video  vote_average  vote_count
# 0  False           8.7       16819
# 1  False           8.7       22545
# 2  False           8.6       10192
# 3  False           8.6       13384
# 4  False           8.6        3928

# %%
movies_df.to_csv('E:/movies.csv')
